# %% [markdown]
# # Lecture 1: Knowledge

# %% [markdown]
# - The goal of this lecture is to learn about how AI can be programmed in order to use the knowledge that it has and use it to draw inferences. We will learn how to make Artificial Intelligence logical.

# %% [markdown]
# ### Knowledge Based Agents:
# - Agents that reason by operating on internal representations of knowledge

# %% [markdown]
# ## Terminologies:
#
# ### Sentence:
# - A sentence is an assertion about the world in a knowledge representation language.
#
# ### Propositional Logic:
# - logic based on propositions.
# - Each Symbol represents some fact. eg:
#     - P = It is raining
#     - Q = Harry visited Hagrid today
# ### Logical Connectives:
# - NOT (~):
#
# ![{F4DE74D1-73CD-45FC-8183-F88B9E2B1F0B}.png](attachment:{F4DE74D1-73CD-45FC-8183-F88B9E2B1F0B}.png)
#
# - AND (^):
#
# ![{6F76EDEA-BC9D-4E63-998A-5246448197A3}.png](attachment:{6F76EDEA-BC9D-4E63-998A-5246448197A3}.png)
#
# - OR (∨):
#
# ![{99CE3D4F-8157-4125-81EB-CBFEDF75627C}.png](attachment:{99CE3D4F-8157-4125-81EB-CBFEDF75627C}.png)
#
# - IMPLICATION (->):
#     - It implies that if P...then   Q OR P implies Q
#
# ![{E182413A-0E31-4AED-8E03-409E9785FFAB}.png](attachment:{E182413A-0E31-4AED-8E03-409E9785FFAB}.png)
#
# - BICONDITIONAL (<->)
#     - It mean "If and only if". We can think of it in the terms of a two sided implication.
